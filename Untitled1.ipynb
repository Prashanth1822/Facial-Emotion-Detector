# %%
# ONLY RUN THESE IF YOU GET ERRORS:
# !pip install tensorflow
# !pip install opencv-python
# !pip install scikit-learn
# !pip install seaborn

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import numpy as np
import pandas as pd
import cv2
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import classification_report, confusion_matrix
import seaborn as sns
import os
from tqdm import tqdm

# ✅ IMPROVED: Consolidated imports
print("✅ All libraries imported successfully!")

class EmotionDataLoader:
    def __init__(self, img_size=(48, 48), augment=True):
        self.img_size = img_size
        self.augment = augment
        self.label_map = {0: 'Angry', 1: 'Disgust', 2: 'Fear', 3: 'Happy', 
                         4: 'Neutral', 5: 'Sad', 6: 'Surprise'}
    
    def smart_enhance_image(self, img):
        """
        BALANCED enhancement - preserves natural features
        """
        if len(img.shape) == 3:
            img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
        
        # Resize
        img = cv2.resize(img, self.img_size)
        
        # Gentle noise reduction
        img = cv2.medianBlur(img, 3)
        
        # Moderate contrast enhancement
        clahe = cv2.createCLAHE(clipLimit=2.0, tileGridSize=(4,4))
        img = clahe.apply(img)
        
        return img
    
    def load_dataset(self, data_dir, test_size=0.2, random_state=42):
        """
        Professional dataset loading with proper train/val split
        """
        images = []
        labels = []
        
        print(f"🔄 Loading dataset from {data_dir}...")
        
        for emotion_label in os.listdir(data_dir):
            emotion_path = os.path.join(data_dir, emotion_label)
            if not os.path.isdir(emotion_path):
                continue
                
            image_files = [f for f in os.listdir(emotion_path) 
                          if f.endswith(('.png', '.jpg', '.jpeg'))]
            
            print(f"📁 {emotion_label}: {len(image_files)} images")
            
            for img_file in tqdm(image_files, desc=emotion_label):
                img_path = os.path.join(emotion_path, img_file)
                img = cv2.imread(img_path)
                
                if img is not None:
                    # Apply balanced enhancement
                    img_enhanced = self.smart_enhance_image(img)
                    images.append(img_enhanced)
                    labels.append(emotion_label)
        
        # Convert to arrays
        images = np.array(images)
        labels = np.array(labels)
        
        # Normalize
        images = images.astype('float32') / 255.0
        images = images.reshape(-1, self.img_size[0], self.img_size[1], 1)
        
        # Encode labels
        le = LabelEncoder()
        labels_encoded = le.fit_transform(labels)
        labels_categorical = keras.utils.to_categorical(labels_encoded, num_classes=7)
        
        # Proper train/validation split
        x_train, x_val, y_train, y_val = train_test_split(
            images, labels_categorical, 
            test_size=test_size, 
            random_state=random_state,
            stratify=labels_encoded
        )
        
        print(f"✅ Dataset loaded successfully!")
        print(f"📊 Training samples: {x_train.shape[0]}")
        print(f"📊 Validation samples: {x_val.shape[0]}")
        print(f"🎯 Classes: {list(self.label_map.values())}")
        
        return x_train, x_val, y_train, y_val, le

# ✅ Initialize data loader
data_loader = EmotionDataLoader(img_size=(48, 48))

# ✅ Load your dataset (adjust path as needed)
x_train, x_val, y_train, y_val, label_encoder = data_loader.load_dataset('train')
# Out:
# ✅ All libraries imported successfully!
# 🔄 Loading dataset from train...
# 📁 Angry: 1561 images
# Angry: 100%|█████████████████| 1561/1561 [00:36<00:00, 42.42it/s]
# 📁 Disgust: 1245 images
# Disgust: 100%|██████████████| 1245/1245 [00:03<00:00, 329.36it/s]
# 📁 Fear: 1264 images
# Fear: 100%|██████████████████| 1264/1264 [00:43<00:00, 29.21it/s]
# 📁 Happy: 2448 images
# Happy: 100%|█████████████████| 2448/2448 [00:39<00:00, 62.43it/s]
# 📁 Neutral: 528 images
# Neutral: 100%|█████████████████| 528/528 [00:27<00:00, 19.22it/s]
# 📁 Sad: 774 images
# Sad: 100%|█████████████████████| 774/774 [00:40<00:00, 18.96it/s]
# 📁 Surprise: 1909 images
# Surprise: 100%|█████████████| 1909/1909 [00:05<00:00, 361.64it/s]
# ✅ Dataset loaded successfully!
# 📊 Training samples: 7783
# 📊 Validation samples: 1946
# 🎯 Classes: ['Angry', 'Disgust', 'Fear', 'Happy', 'Neutral', 'Sad', 'Surprise']

# %%
class AdvancedEmotionModel:
    def __init__(self, input_shape=(48, 48, 1), num_classes=7):
        self.input_shape = input_shape
        self.num_classes = num_classes
        self.model = None
    
    def build_model(self, architecture='advanced_cnn'):
        """
        Build different model architectures
        """
        if architecture == 'advanced_cnn':
            return self._build_advanced_cnn()
        elif architecture == 'deeper_cnn':
            return self._build_deeper_cnn()
        else:
            return self._build_basic_cnn()
    
    def _build_advanced_cnn(self):
        """
        Advanced CNN with residual connections and attention
        """
        model = keras.Sequential([
            # Input layer
            layers.Input(shape=self.input_shape),
            
            # First Conv Block
            layers.Conv2D(32, (3, 3), activation='relu', padding='same'),
            layers.BatchNormalization(),
            layers.Conv2D(32, (3, 3), activation='relu', padding='same'),
            layers.BatchNormalization(),
            layers.MaxPooling2D((2, 2)),
            layers.Dropout(0.25),
            
            # Second Conv Block
            layers.Conv2D(64, (3, 3), activation='relu', padding='same'),
            layers.BatchNormalization(),
            layers.Conv2D(64, (3, 3), activation='relu', padding='same'),
            layers.BatchNormalization(),
            layers.MaxPooling2D((2, 2)),
            layers.Dropout(0.3),
            
            # Third Conv Block
            layers.Conv2D(128, (3, 3), activation='relu', padding='same'),
            layers.BatchNormalization(),
            layers.Conv2D(128, (3, 3), activation='relu', padding='same'),
            layers.BatchNormalization(),
            layers.MaxPooling2D((2, 2)),
            layers.Dropout(0.4),
            
            # Fourth Conv Block
            layers.Conv2D(256, (3, 3), activation='relu', padding='same'),
            layers.BatchNormalization(),
            layers.Conv2D(256, (3, 3), activation='relu', padding='same'),
            layers.BatchNormalization(),
            layers.GlobalAveragePooling2D(),
            layers.Dropout(0.5),
            
            # Dense Layers
            layers.Dense(512, activation='relu'),
            layers.BatchNormalization(),
            layers.Dropout(0.5),
            
            layers.Dense(256, activation='relu'),
            layers.BatchNormalization(),
            layers.Dropout(0.4),
            
            # Output
            layers.Dense(self.num_classes, activation='softmax')
        ])
        
        return model
    
    def _build_deeper_cnn(self):
        """
        Even deeper architecture for complex patterns
        """
        model = keras.Sequential([
            layers.Input(shape=self.input_shape),
            
            # Block 1
            layers.Conv2D(64, (3, 3), activation='relu', padding='same'),
            layers.BatchNormalization(),
            layers.Conv2D(64, (3, 3), activation='relu', padding='same'),
            layers.BatchNormalization(),
            layers.MaxPooling2D((2, 2)),
            layers.Dropout(0.25),
            
            # Block 2
            layers.Conv2D(128, (3, 3), activation='relu', padding='same'),
            layers.BatchNormalization(),
            layers.Conv2D(128, (3, 3), activation='relu', padding='same'),
            layers.BatchNormalization(),
            layers.MaxPooling2D((2, 2)),
            layers.Dropout(0.3),
            
            # Block 3
            layers.Conv2D(256, (3, 3), activation='relu', padding='same'),
            layers.BatchNormalization(),
            layers.Conv2D(256, (3, 3), activation='relu', padding='same'),
            layers.BatchNormalization(),
            layers.MaxPooling2D((2, 2)),
            layers.Dropout(0.4),
            
            # Block 4
            layers.Conv2D(512, (3, 3), activation='relu', padding='same'),
            layers.BatchNormalization(),
            layers.Conv2D(512, (3, 3), activation='relu', padding='same'),
            layers.BatchNormalization(),
            layers.GlobalAveragePooling2D(),
            layers.Dropout(0.5),
            
            # Classifier
            layers.Dense(1024, activation='relu'),
            layers.BatchNormalization(),
            layers.Dropout(0.5),
            
            layers.Dense(512, activation='relu'),
            layers.BatchNormalization(),
            layers.Dropout(0.4),
            
            layers.Dense(self.num_classes, activation='softmax')
        ])
        
        return model

# ✅ Initialize and build model
model_builder = AdvancedEmotionModel()
model = model_builder.build_model('advanced_cnn')

# ✅ Professional compilation
model.compile(
    optimizer=keras.optimizers.Adam(learning_rate=0.001),
    loss='categorical_crossentropy',
    metrics=['accuracy', 
             keras.metrics.Precision(name='precision'),
             keras.metrics.Recall(name='recall')]
)

print("✅ Advanced Model Built Successfully!")
model.summary()
# Out:
# ✅ Advanced Model Built Successfully!
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┓
# ┃ Layer (type)             ┃ Output Shape       ┃    Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━┩
# │ conv2d (Conv2D)          │ (None, 48, 48, 32) │        320 │
# ├──────────────────────────┼────────────────────┼────────────┤
# │ batch_normalization      │ (None, 48, 48, 32) │        128 │
# │ (BatchNormalization)     │                    │            │
# ├──────────────────────────┼────────────────────┼────────────┤
# │ conv2d_1 (Conv2D)        │ (None, 48, 48, 32) │      9,248 │
# ├──────────────────────────┼────────────────────┼────────────┤
# │ batch_normalization_1    │ (None, 48, 48, 32) │        128 │
# │ (BatchNormalization)     │                    │            │
# ├──────────────────────────┼────────────────────┼────────────┤
# │ max_pooling2d            │ (None, 24, 24, 32) │          0 │
# ...

# %%
class ProfessionalTrainer:
    def __init__(self, model):
        self.model = model
        self.history = None
    
    def setup_callbacks(self):
        """
        Professional training callbacks
        """
        callbacks = [
            # Reduce learning rate when validation loss plateaus
            keras.callbacks.ReduceLROnPlateau(
                monitor='val_loss',
                factor=0.5,
                patience=5,
                min_lr=1e-7,
                verbose=1
            ),
            
            # Early stopping to prevent overfitting
            keras.callbacks.EarlyStopping(
                monitor='val_loss',
                patience=15,
                restore_best_weights=True,
                verbose=1
            ),
            
            # Model checkpointing
            keras.callbacks.ModelCheckpoint(
                'best_emotion_model.h5',
                monitor='val_accuracy',
                save_best_only=True,
                mode='max',
                verbose=1
            ),
            
            # TensorBoard for visualization
            keras.callbacks.TensorBoard(
                log_dir='./logs',
                histogram_freq=1
            )
        ]
        
        return callbacks
    
    def train_model(self, x_train, y_train, x_val, y_val, epochs=100, batch_size=32):
        """
        Professional training with monitoring
        """
        print("🚀 Starting professional training...")
        
        callbacks = self.setup_callbacks()
        
        self.history = self.model.fit(
            x_train, y_train,
            batch_size=batch_size,
            epochs=epochs,
            validation_data=(x_val, y_val),
            callbacks=callbacks,
            verbose=1,
            shuffle=True
        )
        
        print("✅ Training completed successfully!")
        return self.history
    
    def plot_training_history(self):
        """
        Comprehensive training visualization
        """
        if self.history is None:
            print("❌ No training history found!")
            return
        
        fig, axes = plt.subplots(2, 2, figsize=(15, 10))
        
        # Accuracy plot
        axes[0, 0].plot(self.history.history['accuracy'], label='Training Accuracy')
        axes[0, 0].plot(self.history.history['val_accuracy'], label='Validation Accuracy')
        axes[0, 0].set_title('Model Accuracy')
        axes[0, 0].set_xlabel('Epoch')
        axes[0, 0].set_ylabel('Accuracy')
        axes[0, 0].legend()
        axes[0, 0].grid(True)
        
        # Loss plot
        axes[0, 1].plot(self.history.history['loss'], label='Training Loss')
        axes[0, 1].plot(self.history.history['val_loss'], label='Validation Loss')
        axes[0, 1].set_title('Model Loss')
        axes[0, 1].set_xlabel('Epoch')
        axes[0, 1].set_ylabel('Loss')
        axes[0, 1].legend()
        axes[0, 1].grid(True)
        
        # Precision plot
        axes[1, 0].plot(self.history.history['precision'], label='Training Precision')
        axes[1, 0].plot(self.history.history['val_precision'], label='Validation Precision')
        axes[1, 0].set_title('Model Precision')
        axes[1, 0].set_xlabel('Epoch')
        axes[1, 0].set_ylabel('Precision')
        axes[1, 0].legend()
        axes[1, 0].grid(True)
        
        # Recall plot
        axes[1, 1].plot(self.history.history['recall'], label='Training Recall')
        axes[1, 1].plot(self.history.history['val_recall'], label='Validation Recall')
        axes[1, 1].set_title('Model Recall')
        axes[1, 1].set_xlabel('Epoch')
        axes[1, 1].set_ylabel('Recall')
        axes[1, 1].legend()
        axes[1, 1].grid(True)
        
        plt.tight_layout()
        plt.show()

# ✅ Initialize trainer
trainer = ProfessionalTrainer(model)

# ✅ Start training
print("🎯 Beginning professional training pipeline...")
history = trainer.train_model(x_train, y_train, x_val, y_val, epochs=100, batch_size=64)

# ✅ Plot training history
trainer.plot_training_history()
# Out:
# 🎯 Beginning professional training pipeline...
# 🚀 Starting professional training...
# Epoch 1/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 690ms/step - accuracy: 0.1835 - loss: 2.6401 - precision: 0.1943 - recall: 0.0818
# Epoch 1: val_accuracy improved from None to 0.25180, saving model to best_emotion_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 102s 736ms/step - accuracy: 0.1997 - loss: 2.4695 - precision: 0.2205 - recall: 0.0811 - val_accuracy: 0.2518 - val_loss: 5.1668 - val_precision: 0.2518 - val_recall: 0.2518 - learning_rate: 0.0010
# Epoch 2/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 673ms/step - accuracy: 0.2491 - loss: 2.0877 - precision: 0.3533 - recall: 0.0922
# ...

# %%
class ModelEvaluator:
    def __init__(self, model, label_encoder):
        self.model = model
        self.label_encoder = label_encoder
        self.label_map = {i: label for i, label in enumerate(label_encoder.classes_)}
    
    def comprehensive_evaluation(self, x_test, y_test):
        """
        Complete model evaluation with multiple metrics
        """
        print("📊 Running comprehensive evaluation...")
        
        # Predictions
        y_pred = self.model.predict(x_test)
        y_pred_classes = np.argmax(y_pred, axis=1)
        y_true_classes = np.argmax(y_test, axis=1)
        
        # Accuracy
        test_loss, test_accuracy, test_precision, test_recall = self.model.evaluate(x_test, y_test, verbose=0)
        
        print(f"🎯 Final Model Performance:")
        print(f"✅ Test Accuracy: {test_accuracy:.4f}")
        print(f"✅ Test Loss: {test_loss:.4f}")
        print(f"✅ Test Precision: {test_precision:.4f}")
        print(f"✅ Test Recall: {test_recall:.4f}")
        
        # Classification report
        print("\n📋 Detailed Classification Report:")
        print(classification_report(y_true_classes, y_pred_classes, 
                                  target_names=self.label_map.values()))
        
        # Confusion matrix
        self.plot_confusion_matrix(y_true_classes, y_pred_classes)
        
        return y_pred_classes, y_true_classes
    
    def plot_confusion_matrix(self, y_true, y_pred):
        """
        Professional confusion matrix visualization
        """
        cm = confusion_matrix(y_true, y_pred)
        plt.figure(figsize=(10, 8))
        sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
                   xticklabels=self.label_map.values(),
                   yticklabels=self.label_map.values())
        plt.title('Confusion Matrix - Emotion Recognition')
        plt.xlabel('Predicted Label')
        plt.ylabel('True Label')
        plt.show()
    
    def predict_single_image(self, image_path):
        """
        Enhanced single image prediction with visualization
        """
        # Load and preprocess image
        img = cv2.imread(image_path)
        if img is None:
            print(f"❌ Could not load image: {image_path}")
            return None
        
        # Preprocess
        img_processed = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
        img_processed = cv2.resize(img_processed, (48, 48))
        img_processed = img_processed.astype('float32') / 255.0
        img_processed = img_processed.reshape(1, 48, 48, 1)
        
        # Prediction
        prediction = self.model.predict(img_processed)
        predicted_class = np.argmax(prediction)
        confidence = np.max(prediction)
        
        # Get top 3 predictions
        top_3_indices = np.argsort(prediction[0])[-3:][::-1]
        top_3_emotions = [self.label_map[i] for i in top_3_indices]
        top_3_confidences = [prediction[0][i] for i in top_3_indices]
        
        # Visualization
        plt.figure(figsize=(12, 4))
        
        # Original image
        plt.subplot(1, 2, 1)
        plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
        plt.title(f'Original Image\n{os.path.basename(image_path)}')
        plt.axis('off')
        
        # Prediction results
        plt.subplot(1, 2, 2)
        colors = plt.cm.RdYlGn(confidence)  # Green for high confidence, Red for low
        plt.barh(top_3_emotions, top_3_confidences, color=[colors, 'lightblue', 'lightcoral'])
        plt.xlabel('Confidence')
        plt.title(f'Top Predictions\nBest: {self.label_map[predicted_class]} ({confidence:.2%})')
        plt.xlim(0, 1)
        
        # Add confidence values on bars
        for i, v in enumerate(top_3_confidences):
            plt.text(v + 0.01, i, f'{v:.2%}', va='center')
        
        plt.tight_layout()
        plt.show()
        
        return {
            'predicted_emotion': self.label_map[predicted_class],
            'confidence': confidence,
            'all_predictions': {self.label_map[i]: float(prediction[0][i]) for i in range(len(self.label_map))}
        }

# ✅ Initialize evaluator
evaluator = ModelEvaluator(model, label_encoder)

# ✅ Comprehensive evaluation
print("🧪 Running final evaluation...")
y_pred, y_true = evaluator.comprehensive_evaluation(x_val, y_val)

# ✅ Test single image predictions
print("\n🔍 Testing single image predictions...")
test_images = [
    'train/sad/sad20.jpg',
    'train/fear/fear36.jpg', 
    'train/disgust/disgust8.jpg',
    'train/disgust/disgust23.jpg'
]

for img_path in test_images:
    if os.path.exists(img_path):
        print(f"\n🎯 Predicting: {img_path}")
        result = evaluator.predict_single_image(img_path)
        if result:
            print(f"✅ Prediction: {result['predicted_emotion']} (Confidence: {result['confidence']:.2%})")
    else:
        print(f"❌ Image not found: {img_path}")
# Out:
# 🧪 Running final evaluation...
# 📊 Running comprehensive evaluation...
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 4s 64ms/step
# 🎯 Final Model Performance:
# ✅ Test Accuracy: 0.6470
# ✅ Test Loss: 0.9727
# ✅ Test Precision: 0.7123
# ✅ Test Recall: 0.5940
#
# 📋 Detailed Classification Report:
#               precision    recall  f1-score   support
#
#        Angry       0.61      0.56      0.58       312
#      Disgust       0.66      0.54      0.59       249
#         Fear       0.50      0.58      0.54       253
#        Happy       0.77      0.86      0.81       490
#      Neutral       0.86      0.58      0.69       105
#          Sad       0.46      0.59      0.51       155
#     Surprise       0.66      0.60      0.63       382
#
#     accuracy                           0.65      1946
#    macro avg       0.65      0.62      0.62      1946
# weighted avg       0.65      0.65      0.65      1946
# 🔍 Testing single image predictions...
#
# 🎯 Predicting: train/sad/sad20.jpg
# ...

# %%
class ModelManager:
    def __init__(self, model, label_encoder):
        self.model = model
        self.label_encoder = label_encoder
    
    def save_complete_model(self, base_name='emotion_detector'):
        """
        Save model in multiple formats for different use cases
        """
        import json
        import datetime
        
        timestamp = datetime.datetime.now().strftime("%Y%m%d_%H%M%S")
        
        # 1. Save Keras model
        model_path = f"{base_name}_{timestamp}.h5"
        self.model.save(model_path)
        print(f"✅ Keras model saved: {model_path}")
        
        # 2. Save model architecture as JSON
        model_json = self.model.to_json()
        json_path = f"{base_name}_{timestamp}.json"
        with open(json_path, 'w') as json_file:
            json_file.write(model_json)
        print(f"✅ Model architecture saved: {json_path}")
        
        # 3. Save label encoder
        label_encoder_path = f"{base_name}_label_encoder_{timestamp}.npy"
        np.save(label_encoder_path, self.label_encoder.classes_)
        print(f"✅ Label encoder saved: {label_encoder_path}")
        
        # 4. Save model metadata
        metadata = {
            'timestamp': timestamp,
            'input_shape': self.model.input_shape,
            'output_classes': len(self.label_encoder.classes_),
            'class_names': self.label_encoder.classes_.tolist(),
            'model_type': 'Emotion Recognition CNN'
        }
        
        metadata_path = f"{base_name}_metadata_{timestamp}.json"
        with open(metadata_path, 'w') as f:
            json.dump(metadata, f, indent=2)
        print(f"✅ Model metadata saved: {metadata_path}")
        
        return {
            'keras_model': model_path,
            'architecture': json_path,
            'label_encoder': label_encoder_path,
            'metadata': metadata_path
        }
    
    def load_saved_model(self, model_path, json_path, label_encoder_path):
        """
        Load saved model and components
        """
        # Load architecture
        with open(json_path, 'r') as json_file:
            model_json = json_file.read()
        
        loaded_model = keras.models.model_from_json(model_json)
        loaded_model.load_weights(model_path)
        
        # Load label encoder
        label_classes = np.load(label_encoder_path, allow_pickle=True)
        loaded_label_encoder = LabelEncoder()
        loaded_label_encoder.classes_ = label_classes
        
        print("✅ Model loaded successfully!")
        return loaded_model, loaded_label_encoder

# ✅ Save the complete model
model_manager = ModelManager(model, label_encoder)
saved_files = model_manager.save_complete_model()

print("\n🎉 TRAINING PIPELINE COMPLETED SUCCESSFULLY!")
print("📁 Saved files:")
for file_type, file_path in saved_files.items():
    print(f"   {file_type}: {file_path}")

print(f"\n🚀 Your emotion recognition model is ready!")
print(f"📊 You can now use it to classify emotions in new images!")
print(f"💡 Use the predict_single_image() function for real-time predictions!")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# ✅ Keras model saved: emotion_detector_20251124_223113.h5
# ✅ Model architecture saved: emotion_detector_20251124_223113.json
# ✅ Label encoder saved: emotion_detector_label_encoder_20251124_223113.npy
# ✅ Model metadata saved: emotion_detector_metadata_20251124_223113.json
#
# 🎉 TRAINING PIPELINE COMPLETED SUCCESSFULLY!
# 📁 Saved files:
#    keras_model: emotion_detector_20251124_223113.h5
#    architecture: emotion_detector_20251124_223113.json
#    label_encoder: emotion_detector_label_encoder_20251124_223113.npy
#    metadata: emotion_detector_metadata_20251124_223113.json
#
# 🚀 Your emotion recognition model is ready!
# 📊 You can now use it to classify emotions in new images!
# ...
